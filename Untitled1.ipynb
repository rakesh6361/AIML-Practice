# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv('C:/Users/Guru Kiran/Downloads/titanic.csv')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df['name']="gpt"

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone name
# 0    man        True  NaN  Southampton    no  False  gpt
# 1  woman       False    C    Cherbourg   yes  False  gpt
# 2  woman       False  NaN  Southampton   yes   True  gpt
# 3  woman       False    C  Southampton   yes  False  gpt
# 4    man        True  NaN  Southampton    no   True  gpt

# %%
df['new fare']=df['fare']+10

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
df['age chetogari']=df['age'].apply(lambda x: 'senior' if x>=25 else 'junior')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
df['survived']=df['survived'].apply(lambda x: "YES" if x=1 else "no")
# Out:
#   Cell In[18], line 1
#     df['survived']=df['survived'].apply(lambda x: "YES" if x=1 else "no")
#                                                   ^
# SyntaxError: expected 'else' after 'if' expression

# %%
df.drop("new fare",axis=1)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
df.drop(["age chetogari","alone"],axis=1,inplace=True)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
df.drop(['sex','age','sibsp','parch','who','embarked','class','deck','embark_town',],axis=1,inplace=True)

# %%
df
# Out:
#      survived  pclass     fare  adult_male alive name  new fare
# 0           0       3   7.2500        True    no  gpt   17.2500
# 1           1       1  71.2833       False   yes  gpt   81.2833
# 2           1       3   7.9250       False   yes  gpt   17.9250
# 3           1       1  53.1000       False   yes  gpt   63.1000
# 4           0       3   8.0500        True    no  gpt   18.0500
# ..        ...     ...      ...         ...   ...  ...       ...
# 886         0       2  13.0000        True    no  gpt   23.0000
# 887         1       1  30.0000       False   yes  gpt   40.0000
# 888         0       3  23.4500       False    no  gpt   33.4500
# 889         1       1  30.0000        True   yes  gpt   40.0000
# 890         0       3   7.7500        True    no  gpt   17.7500
#
# [891 rows x 7 columns]

# %%
df.drop([800,890])
# Out:
#      survived  pclass     fare  adult_male alive name  new fare
# 0           0       3   7.2500        True    no  gpt   17.2500
# 1           1       1  71.2833       False   yes  gpt   81.2833
# 2           1       3   7.9250       False   yes  gpt   17.9250
# 3           1       1  53.1000       False   yes  gpt   63.1000
# 4           0       3   8.0500        True    no  gpt   18.0500
# ..        ...     ...      ...         ...   ...  ...       ...
# 885         0       3  29.1250       False    no  gpt   39.1250
# 886         0       2  13.0000        True    no  gpt   23.0000
# 887         1       1  30.0000       False   yes  gpt   40.0000
# 888         0       3  23.4500       False    no  gpt   33.4500
# 889         1       1  30.0000        True   yes  gpt   40.0000
#
# [889 rows x 7 columns]

# %%
df.drop([50,100,51,58,90,75,85,65,155])
# Out:
#      survived  pclass     fare  adult_male alive name  new fare
# 0           0       3   7.2500        True    no  gpt   17.2500
# 1           1       1  71.2833       False   yes  gpt   81.2833
# 2           1       3   7.9250       False   yes  gpt   17.9250
# 3           1       1  53.1000       False   yes  gpt   63.1000
# 4           0       3   8.0500        True    no  gpt   18.0500
# ..        ...     ...      ...         ...   ...  ...       ...
# 886         0       2  13.0000        True    no  gpt   23.0000
# 887         1       1  30.0000       False   yes  gpt   40.0000
# 888         0       3  23.4500       False    no  gpt   33.4500
# 889         1       1  30.0000        True   yes  gpt   40.0000
# 890         0       3   7.7500        True    no  gpt   17.7500
#
# [882 rows x 7 columns]

# %%
df.loc[len(df)]=[1,3,7.2500,'True','no','gpt',17.2500]

# %%
df
# Out:
#      survived  pclass     fare adult_male alive name  new fare
# 0           0       3   7.2500       True    no  gpt   17.2500
# 1           1       1  71.2833      False   yes  gpt   81.2833
# 2           1       3   7.9250      False   yes  gpt   17.9250
# 3           1       1  53.1000      False   yes  gpt   63.1000
# 4           0       3   8.0500       True    no  gpt   18.0500
# ..        ...     ...      ...        ...   ...  ...       ...
# 887         1       1  30.0000      False   yes  gpt   40.0000
# 888         0       3  23.4500      False    no  gpt   33.4500
# 889         1       1  30.0000       True   yes  gpt   40.0000
# 890         0       3   7.7500       True    no  gpt   17.7500
# 891         1       3   7.2500       True    no  gpt   17.2500
#
# [892 rows x 7 columns]

# %%
df.loc[891]
# Out:
# survived          1
# pclass            3
# fare           7.25
# adult_male     True
# alive            no
# name            gpt
# new fare      17.25
# Name: 891, dtype: object

# %%
df=df.dropna()## any null values delete

# %%
a=df["pclass"].value_counts()
a
# Out:
# pclass
# 3    492
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
plt.bar(a.index,a.values)
# Out:
# <BarContainer object of 3 artists>

# %%
c=df['pclass'].value_counts()
c
# Out:
# pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
c.plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
c.plot(kind="bar")
# Out:
# <Axes: xlabel='pclass'>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
temp={
    "days":['d1','d2','d3','d4','d5','d6','d7'],
    "temprature":[30,50,40,60,70,75,85]
}
df=pd.DataFrame(temp)
print(df)
plt.bar(df['days'],df['temprature'])
# Out:
#   days  temprature
# 0   d1          30
# 1   d2          50
# 2   d3          40
# 3   d4          60
# 4   d5          70
# 5   d6          75
# 6   d7          85
# <BarContainer object of 7 artists>

# %%
df.plot('days','temprature',kind="bar")
# Out:
# <Axes: xlabel='days'>

# %%
df.plot('days','temprature',kind="pie")
# Out:
# <Axes: ylabel='temprature'>

# %%
a=df["pclass"].value_counts()

# %%
plt.plot(df['days'],df['days'].value_counts())

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv('C:/Users/Guru Kiran/Downloads/titanic.csv')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
a=df['sex'].value_counts()
a
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
a.plot(kind="bar")
# Out:
# <Axes: xlabel='sex'>

# %%
c=df[['pclass','sex']].value_counts().unstack()
c
c.plot(kind="bar")
# Out:
# <Axes: xlabel='pclass'>

# %%
a=df.groupby(['pclass','sex']).size().unstack()
a
a.plot(kind="bar")
# Out:
# <Axes: xlabel='pclass'>

# %%
c=df[['pclass','embarked']].value_counts().unstack()
c
c.plot(kind="bar")
# Out:
# <Axes: xlabel='pclass'>
